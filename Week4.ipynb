# %% [markdown]
# # Capstone Project The Battle of Neighborhoods (Week 1)
#
# ## Problem Description
# Nowadays, there are a lot of food bloggers in each and every city, who go around discovering places to fillup our stomach and heart everytime we feel hungry.<br>
# So here I planned to group together places where you would find different genres of food establishments. <br>
# I plan to use a density based clustering algorithm for this project, since I wouldn't know how many such clusters would form in each borough.
#
# ## Data Description
# The dataset to be used would be the New-York dataset which was previously used in Optional Assignment of Week-2.<br>
# The types of establishments I'll be targeting are (but not limited to) restaurants, cafes, bars, delis, bakeries, bistros and more.<br>
# I plan segregate these places from others for each borough, and group them together. If possible, I may also provide a ranking for each cluster.

# %% [markdown]
# Loading the libarries needed for the project, alongwith my Foursquare API credentials

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')


CLIENT_ID = 'GOB3JCHBYQXPYCANCHMHZFU1JD3JHVQ1JKTDUYKSZQRGG1IH' # your Foursquare ID
CLIENT_SECRET = 'TYXODU3E0FYDVNFBAECEEV2AMDBIK0NYPYRN5MH2FBKNFEVZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print("Credentials Approved !")
# Out:
# Libraries imported.
# Credentials Approved !

# %% [markdown]
# Loading the JSON file

# %%
#!wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
# Out:
# Data downloaded!

# %% [markdown]
# Creating a dataframe for the data

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

neighborhoods_data = newyork_data['features']

# %% [markdown]
# Loading data into the dataframe

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# Shuffling the rows within the dataframe<br>(This step is totally optional)<br>Then we view how the dataframe looks like

# %%
neighborhoods = neighborhoods.sample(frac=1).reset_index(drop=True)
neighborhoods.head()
# Out:
#          Borough         Neighborhood   Latitude  Longitude
# 0         Queens            Hillcrest  40.723825 -73.797603
# 1  Staten Island          Great Kills  40.549480 -74.149324
# 2          Bronx  Kingsbridge Heights  40.870392 -73.901523
# 3         Queens             Bellaire  40.733014 -73.738892
# 4         Queens      Oakland Gardens  40.745619 -73.754950

# %%
LIMIT = 500 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# %%
def getNearbyVenues(names, latitudes, longitudes, radius):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
ny_venues = getNearbyVenues(names=neighborhoods.Borough.unique(),
                                   latitudes=neighborhoods.Latitude,
                                   longitudes=neighborhoods.Longitude,
                                radius=radius)
# Out:
# Queens
# Staten Island
# Bronx
# Brooklyn
# Manhattan

# %%
ny_venues
# Out:
#       Neighborhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0           Queens               40.723825               -73.797603
# 1           Queens               40.723825               -73.797603
# 2           Queens               40.723825               -73.797603
# 3           Queens               40.723825               -73.797603
# 4           Queens               40.723825               -73.797603
# 5           Queens               40.723825               -73.797603
# 6           Queens               40.723825               -73.797603
# 7           Queens               40.723825               -73.797603
# 8           Queens               40.723825               -73.797603
# 9           Queens               40.723825               -73.797603
# 10          Queens               40.723825               -73.797603
# 11          Queens               40.723825               -73.797603
# 12          Queens               40.723825               -73.797603
# 13          Queens               40.723825               -73.797603
# 14          Queens               40.723825               -73.797603
# 15          Queens               40.723825               -73.797603
# 16          Queens               40.723825               -73.797603
# 17          Queens               40.723825               -73.797603
# 18   Staten Island               40.549480               -74.149324
# 19   Staten Island               40.549480               -74.149324
# 20   Staten Island               40.549480               -74.149324
# 21   Staten Island               40.549480               -74.149324
# 22   Staten Island               40.549480               -74.149324
# 23   Staten Island               40.549480               -74.149324
# 24   Staten Island               40.549480               -74.149324
# 60   MTA New York City Bus - Bx3/Bx9/Bx32 @ W. King...       40.868305
# 61           MTA Bus - Bx3 (Sedgwick Ave. & 231st St.)       40.872550
# 62                                   Washington's Walk       40.872555
# 63                               Jerome Park Reservoir       40.872584
# 64                                   Yu Hua Restaurant       40.868194
# 65                       Kennedy Fried Chicken & Pizza       40.867821
# 66                                          Manny deli       40.872926
# 67                                                CFSC       40.867805
# 68                                         Carman Cafe       40.871159
# 69                                     Formaggio Pizza       40.873027
# 70                                         Fruit Stand       40.872942
# 71                                           Yo-Burger       40.872431
# 72                          Caridad Spanish Restaurant       40.871832
# 73                                         King's Farm       40.867376
# 74                            Lehman College Ballfield       40.871007
# 75                                 Cara Mia Restaurant       40.730407
# 76                                          China King       40.728896
# 77                                     Winchesters bar       40.733303
# 78                                     Winchester Deli       40.732970
# 79                     Dunkin' Donuts / Baskin Robbins       40.735839
# 80                                            Key Food       40.730929
# 81               Springfield blvd & Francis Lewis blvd       40.729097
# 82                                     Winchester Deli       40.730402
# 83                                    Silvermoon Diner       40.730397
# 84   MTA Q43 Bus Stop (Hillside Avenue and Range St...       40.733174
# 85                                     Gino's Pizzeria       40.748445
# 86                            Bi Won Korean Restaurant       40.747491
# 87                                       Flex Hot Yoga       40.749555
# 88                             Slim's Bagels & Bialy's       40.749271
# 89                                 Fukuoka Shabu Shabu       40.748990
# 90                                         FlexHotYoga       40.749082
# 91                                     Chilsung Garden       40.749320
# 92                                     Little Dumpling       40.749046
# 93                                        Rolly Kimbab       40.748531
# 94                                      Baskin-Robbins       40.747537
# 95                                       Empire Garden       40.748521
# 96                                           Red Mango       40.748587
# 97                                          Chase Bank       40.748794
# 98                                                 GNC       40.748844
# 99                              River Japanese Cuisine       40.748028
# 100                                     Dunkin' Donuts       40.748251
# 101                                           Rite Aid       40.748324
# 102                               Saigon Asian Cuisine       40.748120
# 103                                           Key Food       40.747926
# 104                      SUBWAY / Nathans / Bubble Tea       40.748569
# 105                                     Dunkin' Donuts       40.747459
# 106                          John Zangler Watch Expert       40.749247
# 107                                        Patoug Food       40.748759
# 108                                  Spring Break Deli       40.748910
#
#      Venue Longitude             Venue Category
# 0         -73.796049  College Academic Building
# 1         -73.794458   College Basketball Court
# 2         -73.799786         Dim Sum Restaurant
# 3         -73.799519             Ice Cream Shop
# 4         -73.799463                 Donut Shop
# 5         -73.800900          Mobile Phone Shop
# 6         -73.800074          Convenience Store
# 7         -73.792534             Shipping Store
# 8         -73.796080                Coffee Shop
# 9         -73.800550              Grocery Store
# 10        -73.796555                 Food Court
# 11        -73.792804                     Market
# 12        -73.799612                Pizza Place
# 13        -73.794978       Fast Food Restaurant
# 14        -73.794799                       Food
# 15        -73.794773          College Cafeteria
# 16        -73.794780          College Cafeteria
# 17        -73.794177                   Pharmacy
# 18        -74.150123        Japanese Restaurant
# 19        -74.150816                Pizza Place
# 20        -74.149746         Italian Restaurant
# 21        -74.151117                Pizza Place
# 22        -74.149498                        Bar
# 23        -74.152180                   Pharmacy
# 24        -74.150157          Food & Drink Shop
# 25        -74.151052              Train Station
# 26        -74.150675             Sandwich Place
# 27        -74.150880                        Bar
# 28        -74.149436         Spanish Restaurant
# 29        -74.150083         Chinese Restaurant
# 30        -74.151570              Grocery Store
# 31        -74.150175         Italian Restaurant
# 32        -74.150653                     Bakery
# 33        -74.149734                Pizza Place
# 34        -74.150441         Falafel Restaurant
# 35        -74.149821         Italian Restaurant
# 36        -74.150406               Liquor Store
# 37        -74.150426             Cosmetics Shop
# 38        -74.151567                  Cafeteria
# 39        -74.150716              Deli / Bodega
# 40        -73.903508         Chinese Restaurant
# 41        -73.903219  Latin American Restaurant
# 42        -73.901349                Coffee Shop
# 43        -73.902104         Mexican Restaurant
# 44        -73.897839      Vietnamese Restaurant
# 45        -73.900199                Pizza Place
# 46        -73.897623                      Diner
# 47        -73.895990         Spanish Restaurant
# 48        -73.899236             Sandwich Place
# 49        -73.904088                Coffee Shop
# 50        -73.902342        Fried Chicken Joint
# 51        -73.902042                Pizza Place
# 52        -73.902088                Pizza Place
# 53        -73.895975                Pizza Place
# 54        -73.896984                   Pharmacy
# 55        -73.901504                Supermarket
# 56        -73.902819                Supermarket
# 57        -73.903152                Pizza Place
# 58        -73.902282                Bus Station
# 59        -73.901298                Coffee Shop
# 60        -73.901190                   Bus Stop
# 61        -73.901820                Bus Station
# 62        -73.900563                       Park
# 63        -73.900643                       Lake
# 64        -73.902394         Chinese Restaurant
# 65        -73.901699        Fried Chicken Joint
# 66        -73.903508              Deli / Bodega
# 67        -73.899017      Check Cashing Service
# 68        -73.896762                       Café
# 69        -73.905368                Pizza Place
# 70        -73.905787                       Food
# 71        -73.906339               Burger Joint
# 72        -73.906700         Spanish Restaurant
# 73        -73.897498                 Restaurant
# 74        -73.895781             Baseball Field
# 75        -73.743181         Italian Restaurant
# 76        -73.737284         Chinese Restaurant
# 77        -73.736561          Convenience Store
# 78        -73.737434              Deli / Bodega
# 79        -73.738111                Coffee Shop
# 80        -73.742478                Supermarket
# 81        -73.738652              Moving Target
# 82        -73.734304              Deli / Bodega
# 83        -73.734288           Greek Restaurant
# 84        -73.733089                Bus Station
# 85        -73.756498                Pizza Place
# 86        -73.755944          Korean Restaurant
# 87        -73.755024                Yoga Studio
# 88        -73.755754                 Bagel Shop
# 89        -73.756717       Taiwanese Restaurant
# 90        -73.754943                Yoga Studio
# 91        -73.755368          Korean Restaurant
# 92        -73.756210         Chinese Restaurant
# 93        -73.756335          Korean Restaurant
# 94        -73.756126             Ice Cream Shop
# 95        -73.756458         Chinese Restaurant
# 96        -73.756174               Dessert Shop
# 97        -73.756093                       Bank
# 98        -73.756568            Supplement Shop
# 99        -73.756349           Sushi Restaurant
# 100       -73.758285                 Donut Shop
# 101       -73.755904                   Pharmacy
# 102       -73.756345      Vietnamese Restaurant
# 103       -73.756323                Supermarket
# 104       -73.756370             Sandwich Place
# 105       -73.756093                 Donut Shop
# 106       -73.756252              Jewelry Store
# 107       -73.757744                       Food
# 108       -73.757574              Deli / Bodega
